# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sklearn.datasets as sd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split 



# defining mean value scaling function

def mean_scaling(x_train):
    for feature in list(x_train.columns):
        mean_value = x_train[feature].mean();
        max_value = x_train[feature].max();
        min_value = x_train[feature].min();
        for j in range(x_train.shape[0]):
            x_train.at[j,feature] =  ( x_train.at[j,feature] - mean_value ) / (max_value - min_value);  
            

def Z_score_normalization
            


# collecting && preprocessing data
data = sd.load_breast_cancer();

dataFrame = pd.DataFrame(data['data'],columns = data['feature_names']);

print(dataFrame.isnull().sum());

dataFrame['label'] = data['target'];

# So , our dataFrame contains features & labels

#So,obviously Data has no missing values 

y_data = dataFrame['label'];
x_data = dataFrame.drop(columns = 'label' , axis = 1);
print('this is the y_data' , y_data);

# scaling our training data

mean_scaling(x_data);

# we should split data into test/train sets using sklearn

x_train , x_test , y_train , y_test  = train_test_split(x_data , y_data , test_size = 0.2 , random_state = 2);
print(x_train.shape , y_train);


# Training our model

model = LogisticRegression();
model.fit(x_train,y_train);
print(model)

# Testing our model

x_train_prediction = model.predict(x_train);
print(accuracy_score(y_train,x_train_prediction))

x_test_prediction = model.predict(x_test);
print(accuracy_score(y_test,x_test_prediction))
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64
# this is the y_data 0      0
# 1      0
# 2      0
# ...
